# %%
import pandas as pd
import matplotlib.pyplot as plt


data = pd.read_csv('big_mac.csv')
df = pd.DataFrame(data)

print("Initial Data:")
print(data.head())


average_usd = data['dollar_price'].mean()
print("\nAverage US dollar price of a Big Mac since 2000: ", average_usd)



country_group = data.groupby('name')['dollar_price'].mean() * 1.53
print("\nAverage US dollar by country")
print(country_group)

plt.bar(country_group.index, country_group.values)
plt.xlabel('Country')
plt.ylabel('Average Price (AUD)')
plt.title('Average Big Mac Price Since 2000')
plt.show()
# Out:
# Initial Data:
#         date iso_a3 currency_code       name  local_price  dollar_ex  \
# 0  1/04/2000    ARG           ARS  Argentina         2.50   1.000000
# 1  1/04/2000    AUS           AUD  Australia         2.59   1.680000
# 2  1/04/2000    BRA           BRL     Brazil         2.95   1.790000
# 3  1/04/2000    GBR           GBP    Britain         1.90   0.632911
# 4  1/04/2000    CAN           CAD     Canada         2.85   1.470000
#
#    dollar_price      USD      EUR      GBP      JPY      CNY
# 0      2.500000  0.11607  0.05007 -0.16722 -0.09864  1.09091
# 1      1.541667 -0.31176 -0.35246 -0.48645 -0.44416  0.28939
# 2      1.648045 -0.26427 -0.30778 -0.45102 -0.40581  0.37836
# 3      3.002000  0.34018  0.26092  0.00000  0.08235  1.51076
# 4      1.938776 -0.13448 -0.18566 -0.35417 -0.30099  0.62152
#
# Average US dollar price of a Big Mac since 2000:  3.32123458680932
#
# Average US dollar by country
# name
# Argentina               4.656696
# ...

# %% [markdown]
# The above chart is a little bit large due to containing all countries. To make the data a little more targeted, I think I should perhaps consider focusing on the average price of a Big Mac (AUD) in G20 countries.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(21, 6), dpi=80)



data = pd.read_csv('big_mac_g20.csv')
df = pd.DataFrame(data)

print("Initial Data:")
print(data.head())


average_usd = data['dollar_price'].mean()
print("\nAverage US dollar price of a Big Mac since 2000: ", average_usd)



country_group = data.groupby('name')['dollar_price'].mean() * 1.53
print("\nAverage US dollar by country")
print(country_group)

plt.bar(country_group.index, country_group.values)
plt.xlabel('Country')
plt.ylabel('Average Price (AUD)')
plt.title('Average Big Mac Price Since 2000')
plt.show()
# Out:
# Initial Data:
#         date iso_a3 currency_code       name  local_price  dollar_ex  \
# 0  1/04/2000    ARG           ARS  Argentina         2.50   1.000000
# 1  1/04/2000    AUS           AUD  Australia         2.59   1.680000
# 2  1/04/2000    BRA           BRL     Brazil         2.95   1.790000
# 3  1/04/2000    GBR           GBP    Britain         1.90   0.632911
# 4  1/04/2000    CAN           CAD     Canada         2.85   1.470000
#
#    dollar_price      USD      EUR      GBP      JPY      CNY
# 0      2.500000  0.11607  0.05007 -0.16722 -0.09864  1.09091
# 1      1.541667 -0.31176 -0.35246 -0.48645 -0.44416  0.28939
# 2      1.648045 -0.26427 -0.30778 -0.45102 -0.40581  0.37836
# 3      3.002000  0.34018  0.26092  0.00000  0.08235  1.51076
# 4      1.938776 -0.13448 -0.18566 -0.35417 -0.30099  0.62152
#
# Average US dollar price of a Big Mac since 2000:  3.100480885591228
#
# Average US dollar by country
# name
# Argentina        4.656696
# Australia        5.815760
# ...

# %% [markdown]
# Now that I have duplicated and updated the .csv file to just include the G20 nations available in the data (all nations except EU nations, who are grouped together), I am able to present the data in a clearer manner.
#
# Additionally, as the country labels were still too close together, I did some research and discovered the figure class. The figure class is a part of the matplotlib module, and allows you to change the size of the figures you generate, meaning I could stretch the graph out to be much wider and allow room for all 16 country labels.
#
# The next step in this process is discovering how to store all of these files on GitHub so that they work seemlessly!

# %% [markdown]
# It seems I have added to github - now how do I edit to add headings and subheadings in Jupyter? Needs further exploration.
